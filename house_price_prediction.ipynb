# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('dataset/housing.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
X= df.drop(['median_house_value'] ,axis=1)
y= df['median_house_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18119    -122.03     37.32                15.0       5132.0          1059.0
# 19699    -121.62     39.09                21.0       2693.0           481.0
# 600      -122.07     37.70                32.0       3400.0           736.0
# 10959    -117.90     33.75                32.0       1893.0           431.0
# 19789    -123.35     40.99                23.0        141.0            59.0
# ...          ...       ...                 ...          ...             ...
# 13812    -117.02     34.89                29.0       3111.0           661.0
# 18988    -121.94     38.38                25.0        182.0            48.0
# 7746     -118.15     33.93                34.0       1745.0           404.0
# 10395    -117.67     33.54                15.0       2423.0           435.0
# 13235    -117.66     34.15                20.0       2524.0           311.0
#
#        population  households  median_income ocean_proximity  \
# 18119      2156.0       982.0         5.6511       <1H OCEAN
# 19699      1337.0       435.0         3.8534          INLAND
# 600        1487.0       694.0         3.0000        NEAR BAY
# 10959      2245.0       426.0         3.7143       <1H OCEAN
# 19789        47.0        23.0         1.1250          INLAND
# ...           ...         ...            ...             ...
# 13812      1530.0       608.0         2.8281          INLAND
# 18988        71.0        52.0         1.0208          INLAND
# 7746       1084.0       410.0         3.3411       <1H OCEAN
# 10395      1366.0       423.0         4.8906       <1H OCEAN
# 13235       965.0       285.0         8.0103          INLAND
#
#        median_house_value
# 18119            404800.0
# 19699             99700.0
# 600              223200.0
# 10959            163000.0
# 19789             66000.0
# ...                   ...
# 13812             69300.0
# 18988             78600.0
# 7746             220500.0
# 10395            181800.0
# 13235            395500.0
#
# [16346 rows x 10 columns]

# %% [markdown]
# # Data visualization and exploration

# %%
train_data.hist(figsize=(10,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18119    -122.03     37.32                15.0       5132.0          1059.0
# 19699    -121.62     39.09                21.0       2693.0           481.0
# 600      -122.07     37.70                32.0       3400.0           736.0
# 10959    -117.90     33.75                32.0       1893.0           431.0
# 19789    -123.35     40.99                23.0        141.0            59.0
#
#        population  households  median_income ocean_proximity  \
# 18119      2156.0       982.0         5.6511       <1H OCEAN
# 19699      1337.0       435.0         3.8534          INLAND
# 600        1487.0       694.0         3.0000        NEAR BAY
# 10959      2245.0       426.0         3.7143       <1H OCEAN
# 19789        47.0        23.0         1.1250          INLAND
#
#        median_house_value
# 18119            404800.0
# 19699             99700.0
# 600              223200.0
# 10959            163000.0
# 19789             66000.0

# %%
new_df = train_data.drop(['ocean_proximity'], axis =1)
new_df.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18119    -122.03     37.32                15.0       5132.0          1059.0
# 19699    -121.62     39.09                21.0       2693.0           481.0
# 600      -122.07     37.70                32.0       3400.0           736.0
# 10959    -117.90     33.75                32.0       1893.0           431.0
# 19789    -123.35     40.99                23.0        141.0            59.0
#
#        population  households  median_income  median_house_value
# 18119      2156.0       982.0         5.6511            404800.0
# 19699      1337.0       435.0         3.8534             99700.0
# 600        1487.0       694.0         3.0000            223200.0
# 10959      2245.0       426.0         3.7143            163000.0
# 19789        47.0        23.0         1.1250             66000.0

# %%
plt.figure(figsize=(12,8))
sns.heatmap(new_df.corr(), annot=True ,cmap='YlGnBu')
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms']+1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms']+1)
train_data['population'] = np.log(train_data['population']+1)
train_data['households'] = np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(10,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7285
# INLAND        5190
# NEAR OCEAN    2084
# NEAR BAY      1784
# ISLAND           3
# Name: count, dtype: int64

# %%
td1=train_data.join(pd.get_dummies(train_data.ocean_proximity).astype(int)).drop(['ocean_proximity'],axis=1)

# %%
td1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18119    -122.03     37.32                15.0     8.543446        6.966024
# 19699    -121.62     39.09                21.0     7.898782        6.177944
# 600      -122.07     37.70                32.0     8.131825        6.602588
# 10959    -117.90     33.75                32.0     7.546446        6.068426
# 19789    -123.35     40.99                23.0     4.955827        4.094345
# ...          ...       ...                 ...          ...             ...
# 13812    -117.02     34.89                29.0     8.043021        6.495266
# 18988    -121.94     38.38                25.0     5.209486        3.891820
# 7746     -118.15     33.93                34.0     7.465083        6.003887
# 10395    -117.67     33.54                15.0     7.793174        6.077642
# 13235    -117.66     34.15                20.0     7.833996        5.743003
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 18119    7.676474    6.890609         5.6511            404800.0          1
# 19699    7.198931    6.077642         3.8534             99700.0          0
# 600      7.305188    6.543912         3.0000            223200.0          0
# 10959    7.716906    6.056784         3.7143            163000.0          1
# 19789    3.871201    3.178054         1.1250             66000.0          0
# ...           ...         ...            ...                 ...        ...
# 13812    7.333676    6.411818         2.8281             69300.0          0
# 18988    4.276666    3.970292         1.0208             78600.0          0
# 7746     6.989335    6.018593         3.3411            220500.0          1
# 10395    7.220374    6.049733         4.8906            181800.0          1
# 13235    6.873164    5.655992         8.0103            395500.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 18119       0       0         0           0
# 19699       1       0         0           0
# 600         0       0         1           0
# 10959       0       0         0           0
# 19789       1       0         0           0
# ...       ...     ...       ...         ...
# 13812       1       0         0           0
# 18988       1       0         0           0
# 7746        0       0         0           0
# 10395       0       0         0           0
# 13235       1       0         0           0
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(12,8))
sns.heatmap(td1.corr(), annot=True ,cmap='YlGnBu',cbar=False)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='latitude', y= 'longitude', data=td1, hue='median_house_value',palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
td1['bedroom_ratio']= td1['total_bedrooms']/td1['total_rooms']
td1['household_room']=td1['total_rooms']/td1['households']

# %%
td1.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18119    -122.03     37.32                15.0     8.543446        6.966024
# 19699    -121.62     39.09                21.0     7.898782        6.177944
# 600      -122.07     37.70                32.0     8.131825        6.602588
# 10959    -117.90     33.75                32.0     7.546446        6.068426
# 19789    -123.35     40.99                23.0     4.955827        4.094345
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 18119    7.676474    6.890609         5.6511            404800.0          1
# 19699    7.198931    6.077642         3.8534             99700.0          0
# 600      7.305188    6.543912         3.0000            223200.0          0
# 10959    7.716906    6.056784         3.7143            163000.0          1
# 19789    3.871201    3.178054         1.1250             66000.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_room
# 18119       0       0         0           0       0.815365        1.239868
# 19699       1       0         0           0       0.782139        1.299646
# 600         0       0         1           0       0.811944        1.242655
# 10959       0       0         0           0       0.804143        1.245949
# 19789       1       0         0           0       0.826168        1.559391

# %%
plt.figure(figsize=(12,8))
sns.heatmap(td1.corr(),annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
X_train,y_train = td1.drop(['median_house_value'], axis=1), td1['median_house_value']

# %%
test_data = X_test.join(y_test)
test_data['total_rooms'] = np.log(test_data['total_rooms']+1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms']+1)
test_data['population'] = np.log(test_data['population']+1)
test_data['households'] = np.log(test_data['households']+1)

# %%
tstd=test_data.join(pd.get_dummies(test_data.ocean_proximity).astype(int)).drop(['ocean_proximity'],axis=1)

# %%
tstd['bedroom_ratio']= tstd['total_bedrooms']/tstd['total_rooms']
tstd['household_room']=tstd['total_rooms']/tstd['households']

# %%
X_test, y_test = tstd.drop(['median_house_value'], axis=1), tstd['median_house_value']

# %%
X_test.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 308      -122.18     37.77                51.0     7.653495        6.156979
# 12528    -121.49     38.56                35.0     7.327781        6.126869
# 4708     -118.35     34.06                48.0     7.211557        5.634790
# 6365     -117.97     34.17                35.0     8.518392        6.744059
# 17448    -120.47     34.63                23.0     7.800573        6.139885
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 308      7.068172    6.084499         3.2552          0       0       0
# 12528    6.895683    6.122493         1.9013          0       1       0
# 4708     6.575076    5.736572         3.7167          1       0       0
# 6365     7.655864    6.701960         4.9968          0       1       0
# 17448    7.239215    6.075346         3.7917          0       0       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_room
# 308           1           0       0.804466        1.257868
# 12528         0           0       0.836115        1.196862
# 4708          0           0       0.781356        1.257119
# 6365          0           0       0.791706        1.271030
# 17448         0           1       0.787107        1.283972

# %%
X_train.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18119    -122.03     37.32                15.0     8.543446        6.966024
# 19699    -121.62     39.09                21.0     7.898782        6.177944
# 600      -122.07     37.70                32.0     8.131825        6.602588
# 10959    -117.90     33.75                32.0     7.546446        6.068426
# 19789    -123.35     40.99                23.0     4.955827        4.094345
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 18119    7.676474    6.890609         5.6511          1       0       0
# 19699    7.198931    6.077642         3.8534          0       1       0
# 600      7.305188    6.543912         3.0000          0       0       0
# 10959    7.716906    6.056784         3.7143          1       0       0
# 19789    3.871201    3.178054         1.1250          0       1       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_room
# 18119         0           0       0.815365        1.239868
# 19699         0           0       0.782139        1.299646
# 600           1           0       0.811944        1.242655
# 10959         0           0       0.804143        1.245949
# 19789         0           0       0.826168        1.559391

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=200)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=200)

# %%
model.score(X_test,y_test)
# Out:
# 0.8124067958682647

# %%
model.predict(X_test)
# Out:
# array([191568.   ,  99147.   , 362134.025, ..., 204496.   , 342854.01 ,
#        396230.09 ])

# %%
y_test
# Out:
# 308      120100.0
# 12528     86900.0
# 4708     385000.0
# 6365     295000.0
# 17448    142200.0
#            ...
# 1994      53000.0
# 18104    409100.0
# 6474     202400.0
# 7902     322700.0
# 8945     413000.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
dat=[[-121.23,         37.82,         14.,            7.521859,      5.786897,
     6.938284,      5.736572,      4.9271,        1.,            0.,
     0.,            0.,            0.,            0.76934399,    1.31121147]]

# %%
model.predict(dat)
# Out:
# c:\Users\Prabesh Baral\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([232242.5])
