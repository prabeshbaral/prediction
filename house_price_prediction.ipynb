# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('dataset/housing.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
X= df.drop(['median_house_value'] ,axis=1)
y= df['median_house_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16782    -122.49     37.68                34.0       3718.0           676.0
# 1419     -122.05     37.97                16.0         60.0            10.0
# 3665     -118.37     34.22                17.0       1787.0           463.0
# 3892     -118.55     34.21                33.0       3910.0           838.0
# 954      -121.92     37.64                46.0       1280.0           209.0
# ...          ...       ...                 ...          ...             ...
# 8719     -118.37     33.84                27.0       3245.0           605.0
# 17043    -122.28     37.49                25.0       7335.0          1157.0
# 6602     -118.16     34.19                42.0       2076.0           462.0
# 2503     -120.46     36.87                20.0       1287.0           310.0
# 917      -121.97     37.52                23.0       4925.0           948.0
#
# ...

# %% [markdown]
# # Data visualization and exploration

# %%
train_data.hist(figsize=(10,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16782    -122.49     37.68                34.0       3718.0           676.0
# 1419     -122.05     37.97                16.0         60.0            10.0
# 3665     -118.37     34.22                17.0       1787.0           463.0
# 3892     -118.55     34.21                33.0       3910.0           838.0
# 954      -121.92     37.64                46.0       1280.0           209.0
#
#        population  households  median_income ocean_proximity  \
# 16782      2510.0       632.0         5.3311      NEAR OCEAN
# 1419         65.0        19.0         6.1359        NEAR BAY
# 3665       1671.0       448.0         3.5521       <1H OCEAN
# 3892       2097.0       810.0         3.8247       <1H OCEAN
# 954         512.0       208.0         5.1406          INLAND
#
#        median_house_value
# 16782            270800.0
# 1419             250000.0
# 3665             151500.0
# 3892             208700.0
# ...

# %%
new_df = train_data.drop(['ocean_proximity'], axis =1)
new_df.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16782    -122.49     37.68                34.0       3718.0           676.0
# 1419     -122.05     37.97                16.0         60.0            10.0
# 3665     -118.37     34.22                17.0       1787.0           463.0
# 3892     -118.55     34.21                33.0       3910.0           838.0
# 954      -121.92     37.64                46.0       1280.0           209.0
#
#        population  households  median_income  median_house_value
# 16782      2510.0       632.0         5.3311            270800.0
# 1419         65.0        19.0         6.1359            250000.0
# 3665       1671.0       448.0         3.5521            151500.0
# 3892       2097.0       810.0         3.8247            208700.0
# 954         512.0       208.0         5.1406            315600.0

# %%
plt.figure(figsize=(12,8))
sns.heatmap(new_df.corr(), annot=True ,cmap='YlGnBu')
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms']+1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms']+1)
train_data['population'] = np.log(train_data['population']+1)
train_data['households'] = np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(10,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7247
# INLAND        5176
# NEAR OCEAN    2092
# NEAR BAY      1829
# ISLAND           2
# Name: count, dtype: int64

# %%
td1=train_data.join(pd.get_dummies(train_data.ocean_proximity).astype(int)).drop(['ocean_proximity'],axis=1)

# %%
td1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16782    -122.49     37.68                34.0     8.221210        6.517671
# 1419     -122.05     37.97                16.0     4.110874        2.397895
# 3665     -118.37     34.22                17.0     7.488853        6.139885
# 3892     -118.55     34.21                33.0     8.271548        6.732211
# 954      -121.92     37.64                46.0     7.155396        5.347108
# ...          ...       ...                 ...          ...             ...
# 8719     -118.37     33.84                27.0     8.085179        6.406880
# 17043    -122.28     37.49                25.0     8.900549        7.054450
# 6602     -118.16     34.19                42.0     7.638680        6.137727
# 2503     -120.46     36.87                20.0     7.160846        5.739793
# 917      -121.97     37.52                23.0     8.502283        6.855409
#
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(td1.corr(), annot=True ,cmap='YlGnBu',cbar=False)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='latitude', y= 'longitude', data=td1, hue='median_house_value',palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
td1['bedroom_ratio']= td1['total_bedrooms']/td1['total_rooms']
td1['household_room']=td1['total_rooms']/td1['households']

# %%
td1.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16782    -122.49     37.68                34.0     8.221210        6.517671
# 1419     -122.05     37.97                16.0     4.110874        2.397895
# 3665     -118.37     34.22                17.0     7.488853        6.139885
# 3892     -118.55     34.21                33.0     8.271548        6.732211
# 954      -121.92     37.64                46.0     7.155396        5.347108
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 16782    7.828436    6.450470         5.3311            270800.0          0
# 1419     4.189655    2.995732         6.1359            250000.0          0
# 3665     7.421776    6.107023         3.5521            151500.0          1
# 3892     7.648740    6.698268         3.8247            208700.0          1
# 954      6.240276    5.342334         5.1406            315600.0          0
#
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(td1.corr(),annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
X_train,y_train = td1.drop(['median_house_value'], axis=1), td1['median_house_value']

# %%
test_data = X_test.join(y_test)
test_data['total_rooms'] = np.log(test_data['total_rooms']+1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms']+1)
test_data['population'] = np.log(test_data['population']+1)
test_data['households'] = np.log(test_data['households']+1)

# %%
tstd=test_data.join(pd.get_dummies(test_data.ocean_proximity).astype(int)).drop(['ocean_proximity'],axis=1)

# %%
tstd['bedroom_ratio']= tstd['total_bedrooms']/tstd['total_rooms']
tstd['household_room']=tstd['total_rooms']/tstd['households']

# %%
X_test, y_test = tstd.drop(['median_house_value'], axis=1), tstd['median_house_value']

# %%
X_test.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16342    -121.32     38.03                16.0     8.305484        6.436150
# 8871     -118.41     34.06                43.0     7.888335        6.322565
# 8624     -118.38     33.88                34.0     7.512618        5.755742
# 19101    -122.62     38.25                20.0     7.543803        6.021023
# 17070    -122.26     37.53                 4.0     8.562931        7.012115
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 16342    7.529943    6.439350         4.8750          0       1       0
# 8871     6.923629    6.228511         4.1411          1       0       0
# 8624     6.712956    5.730100         5.0602          1       0       0
# 19101    6.717805    5.983936         2.8750          1       0       0
# 17070    7.433075    6.811244         6.2007          0       0       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_room
# ...

# %%
X_train.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16782    -122.49     37.68                34.0     8.221210        6.517671
# 1419     -122.05     37.97                16.0     4.110874        2.397895
# 3665     -118.37     34.22                17.0     7.488853        6.139885
# 3892     -118.55     34.21                33.0     8.271548        6.732211
# 954      -121.92     37.64                46.0     7.155396        5.347108
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 16782    7.828436    6.450470         5.3311          0       0       0
# 1419     4.189655    2.995732         6.1359          0       0       0
# 3665     7.421776    6.107023         3.5521          1       0       0
# 3892     7.648740    6.698268         3.8247          1       0       0
# 954      6.240276    5.342334         5.1406          0       1       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_room
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=200)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=200)

# %%
model.score(X_test,y_test)
# Out:
# 0.8156481654349612

# %%
model.predict(X_test)
# Out:
# array([156219.5 , 448977.54, 380471.07, ...,  73581.  , 177998.  ,
#        175514.5 ])

# %%
y_test
# Out:
# 16342    143100.0
# 8871     500001.0
# 8624     453700.0
# 19101    189100.0
# 17070    311800.0
#            ...
# 16137    500001.0
# 4132     214200.0
# 12439     66700.0
# 722      180900.0
# 7958     163000.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
dat=[[-121.23,         37.82,         14.,            7.521859,      5.786897,
     6.938284,      5.736572,      4.9271,        1.,            0.,
     0.,            0.,            0.,            0.76934399,    1.31121147]]

# %%
feature_names = ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 
                         'total_bedrooms', 'population', 'households', 'median_income'
                         , '<1H OCEAN', 'INLAND', 
                         'ISLAND', 'NEAR BAY', 'NEAR OCEAN','bedroom_ratio','household_room']
input_df = pd.DataFrame(dat, columns=feature_names)

# %%
model.predict(input_df)
# Out:
# array([231417.005])
